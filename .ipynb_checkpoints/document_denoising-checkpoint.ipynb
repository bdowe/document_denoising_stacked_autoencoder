# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
'''
https://www.kaggle.com/dimakyn/keras-cnn-autoencoder
'''
# Out:
# '\nhttps://www.kaggle.com/dimakyn/keras-cnn-autoencoder\n'

# %%
import os
import glob

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import UpSampling2D
from tensorflow.keras.layers import Reshape

from sklearn.model_selection import train_test_split

# %%
def im_show(im_name):
    plt.figure(figsize=(20,8))
    img = cv2.imread(im_name, 0)
    plt.imshow(img, cmap="gray")
    print(f"[INFO] Image shape: {img.shape} ")
im_show("datasets/train/77.png")
im_show("datasets/train_cleaned/77.png")
# Out:
# [INFO] Image shape: (420, 540)
# [INFO] Image shape: (420, 540)

# %%
TRAIN_IMAGES = glob.glob('datasets/train/*.png')
CLEAN_IMAGES = glob.glob('datasets/train_cleaned/*.png')
TEST_IMAGES = glob.glob('datasets/test/*.png')
print(f"[INFO] Number of train pictures: {len(TRAIN_IMAGES)}")
print(f"[INFO] Number of train_cleaned pictures: {len(CLEAN_IMAGES)}")
print(f"[INFO] Number of test pictures: {len(TEST_IMAGES)}")
# Out:
# [INFO] Number of train pictures: 144
# [INFO] Number of train_cleaned pictures: 144
# [INFO] Number of test pictures: 72

# %%
IMG_W = 258
IMG_H = 540
BS = 20
EPOCHS = 200

# %%
from image_loader import ImageLoader

# %%
x_train = ImageLoader.load_image(TRAIN_IMAGES, IMG_W, IMG_H)
y_train = ImageLoader.load_image(CLEAN_IMAGES, IMG_W, IMG_H)
x_test = ImageLoader.load_image(TEST_IMAGES, IMG_W, IMG_H)

print(f"[INFO] x_train shape: {x_train.shape}")
print(f"[INFO] y_train shape: {y_train.shape}")
print(f"[INFO] x_test shape: {x_test.shape}")
# Out:
# [INFO] x_train shape: (144, 258, 540, 1)
# [INFO] y_train shape: (144, 258, 540, 1)
# [INFO] x_test shape: (72, 258, 540, 1)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.15, 
                                                  random_state=42)
print(f"[INFO] train shape: {x_train.shape} and {y_train.shape}")
print(f"[INFO] validation shape: {x_val.shape} and {y_val.shape}")
# Out:
# [INFO] train shape: (122, 258, 540, 1) and (122, 258, 540, 1)
# [INFO] validation shape: (22, 258, 540, 1) and (22, 258, 540, 1)

# %%
from deep_conv_autoencoder import AE

autoencoder = AE.create_model(IMG_W, IMG_H)
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 258, 540, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 258, 540, 64)      640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 129, 270, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 129, 270, 64)      36928
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 258, 540, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 258, 540, 1)       577
# ...
# Total params: 38,145
# Trainable params: 38,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss',
                                       min_delta=0,
                                       patience=5,
                                       verbose=1, 
                                       mode='auto')
checkpoint = ModelCheckpoint('document_denoising_1.hdf5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
history = autoencoder.fit(x_train, y_train,
                         batch_size=BS,
                         epochs=EPOCHS,
                         validation_data=([x_val, x_val], y_val),
                         callbacks=[early_stopping, checkpoint]
                        )
# Out:
# Train on 122 samples, validate on 22 samples
# Epoch 1/200
# 120/122 [============================>.] - ETA: 0s - loss: 0.1597
# Epoch 00001: val_loss improved from inf to 0.07932, saving model to document_denoising_1.hdf5
# 122/122 [==============================] - 4s 32ms/sample - loss: 0.1585 - val_loss: 0.0793
# Epoch 2/200
# 120/122 [============================>.] - ETA: 0s - loss: 0.0715
# Epoch 00002: val_loss improved from 0.07932 to 0.07437, saving model to document_denoising_1.hdf5
# 122/122 [==============================] - 1s 8ms/sample - loss: 0.0716 - val_loss: 0.0744
# Epoch 3/200
# 100/122 [=======================>......] - ETA: 0s - loss: 0.0729WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# ---------------------------------------------------------------------------
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1250503f1f39> in <module>
# ----> 1 plt.plot(history.history['loss'])
#       2 plt.plot(history.history['val_loss'])
#       3 plt.title('Model loss')
#       4 plt.ylabel('Loss')
#       5 plt.xlabel('Epoch')
#
# NameError: name 'history' is not defined

# %%
preds = autoencoder.predict(x_test)

# %%
def plot_digits(*args):
    args = [x.squeeze() for x in args]
    n = min([x.shape[0] for x in args])
    
    plt.figure(figsize=(2*n, 2*len(args)))
    for j in range(n):
        for i in range(len(args)):
            ax = plt.subplot(len(args), n, i*n + j + 1)
            plt.imshow(args[i][j])
            plt.gray()
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)

    plt.show()

plot_digits(x_test[:5], preds[:5])

# %%
import os
import glob

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras.layers import Input, Dense, Activation, BatchNormalization, Flatten, Conv2D, MaxPooling2D, Dropout, UpSampling2D, Reshape, concatenate

from sklearn.model_selection import train_test_split

# %%
TRAIN_IMAGES = glob.glob('train/*.png')
CLEAN_IMAGES = glob.glob('train_cleaned/*.png')
TEST_IMAGES = glob.glob('test/*.png')
print(f"[INFO] Number of train pictures: {len(TRAIN_IMAGES)}")
print(f"[INFO] Number of train_cleaned pictures: {len(CLEAN_IMAGES)}")
print(f"[INFO] Number of test pictures: {len(TEST_IMAGES)}")
# Out:
# [INFO] Number of train pictures: 0
# [INFO] Number of train_cleaned pictures: 0
# [INFO] Number of test pictures: 0

# %%
IMG_W = 258
IMG_H = 540
BS = 20
EPOCHS = 1000

# %%
def im_show(im_name, blur=False):
    plt.figure(figsize=(20,8))
    img = cv2.imread(im_name, 0)
    if blur:
        img = cv2.medianBlur(img, 3)
    plt.imshow(img, cmap="gray")
    print(f"[INFO] Image shape: {img.shape} ")
im_show("datasets/train/77.png")
im_show("datasets/train/77.png", True)
im_show("datasets/train_cleaned/77.png")
# Out:
# [INFO] Image shape: (420, 540)
# [INFO] Image shape: (420, 540)
# [INFO] Image shape: (420, 540)

# %%
autoencoder = load_model('document_denoising_1.hdf5')

# %%
x_train = ImageLoader.load_image(TRAIN_IMAGES, IMG_W, IMG_H)
x_train_blur = ImageLoader.load_image_blur(TRAIN_IMAGES, IMG_W, IMG_H)
x_train_canny_dilate_erode = ImageLoader.load_image_canny_dilate_erode(TRAIN_IMAGES, IMG_W, IMG_H)
x_train_threshold_binary = ImageLoader.load_image_threshold(TRAIN_IMAGES, IMG_W, IMG_H, 'binary')
x_train_threshold_gaussian = ImageLoader.load_image_threshold(TRAIN_IMAGES, IMG_W, IMG_H)
x_train_threshold_mean = ImageLoader.load_image_threshold(TRAIN_IMAGES, IMG_W, IMG_H, 'adaptive_mean')
x_train_autoencoder = autoencoder.predict(x_train)
y_train = ImageLoader.load_image(CLEAN_IMAGES, IMG_W, IMG_H)


x_test = ImageLoader.load_image(TEST_IMAGES, IMG_W, IMG_H)
x_test_blur = ImageLoader.load_image_blur(TEST_IMAGES, IMG_W, IMG_H)
x_test_canny_dilate_erode = ImageLoader.load_image_canny_dilate_erode(TEST_IMAGES, IMG_W, IMG_H)
x_test_threshold_binary = ImageLoader.load_image_threshold(TEST_IMAGES, IMG_W, IMG_H, 'binary')
x_test_threshold_gaussian = ImageLoader.load_image_threshold(TEST_IMAGES, IMG_W, IMG_H)
x_test_threshold_mean = ImageLoader.load_image_threshold(TEST_IMAGES, IMG_W, IMG_H, 'adaptive_mean')
x_test_autoencoder = autoencoder.predict(x_test)

print(f"[INFO] x_train shape: {x_train.shape}")
print(f"[INFO] x_train_blur shape: {x_train_blur.shape}")
print(f"[INFO] x_train_canny_dilate_erode shape: {x_train_canny_dilate_erode.shape}")
print(f"[INFO] x_train_threshold shape: {x_train_threshold_binary.shape}")
print(f"[INFO] x_train_threshold shape: {x_train_threshold_gaussian.shape}")
print(f"[INFO] x_train_threshold shape: {x_train_threshold_mean.shape}")
print(f"[INFO] x_train_autoencoder shape: {x_train_autoencoder.shape}")
print(f"[INFO] y_train shape: {y_train.shape}")

print(f"[INFO] x_test shape: {x_test.shape}")
print(f"[INFO] x_test_blur shape: {x_test_blur.shape}")
print(f"[INFO] x_test_canny_dilate_erode shape: {x_test_canny_dilate_erode.shape}")
print(f"[INFO] x_test_threshold shape: {x_test_threshold_binary.shape}")
print(f"[INFO] x_test_threshold shape: {x_test_threshold_gaussian.shape}")
print(f"[INFO] x_test_threshold shape: {x_test_threshold_mean.shape}")
print(f"[INFO] x_test_autoencoder shape: {x_test_autoencoder.shape}")

# %%
#### Need to make sure all X's and y's match up - do some tests
## https://stackoverflow.com/questions/49829023/train-test-split-with-multiple-features

# %%
x_train, x_val, x_train_blur, x_val_blur, x_train_canny_dilate_erode, x_val_canny_dilate_erode, x_train_threshold_binary, x_val_threshold_binary, x_train_threshold_gaussian, x_val_threshold_gaussian, x_train_threshold_mean, x_val_threshold_mean, x_train_autoencoder, x_val_autoencoder, y_train, y_val = train_test_split(x_train, x_train_blur, x_train_canny_dilate_erode, x_train_threshold_binary, x_train_threshold_gaussian, x_train_threshold_mean, x_train_autoencoder, y_train, test_size=0.15, random_state=42)
print(f"[INFO] train shape: {x_train.shape} and {y_train.shape}")
print(f"[INFO] blur shape: {x_train_blur.shape} and {x_val_blur.shape}")
print(f"[INFO] validation shape: {x_val.shape} and {y_val.shape}")
# Out:
# [INFO] train shape: (122, 258, 540, 1) and (122, 258, 540, 1)
# [INFO] blur shape: (122, 258, 540, 1) and (22, 258, 540, 1)
# [INFO] validation shape: (22, 258, 540, 1) and (22, 258, 540, 1)

# %%
def create_deep_conv_stacker():
    input_layer = Input(shape=(IMG_W, IMG_H, 1))
    input_layer_blur = Input(shape=(IMG_W, IMG_H, 1))
    input_layer_canny_dilate_erode = Input(shape=(IMG_W, IMG_H, 1))
    input_layer_threshold_binary = Input(shape=(IMG_W, IMG_H, 1))
    input_layer_threshold_gaussian = Input(shape=(IMG_W, IMG_H, 1))
    input_layer_threshold_mean = Input(shape=(IMG_W, IMG_H, 1))
    input_layer_autoencoder = Input(shape=(IMG_W, IMG_H, 1))
    x = concatenate([input_layer, input_layer_blur, input_layer_canny_diate_erode, input_threshold_binary, input_threshold_gaussian, input_threshold_mean, input_autoencoder],axis=-1)

    # encoder
    h = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    h = MaxPooling2D((2, 2), padding='same')(h)

    # decoder
    h = Conv2D(64, (3, 3), activation='relu', padding='same')(h)
    h = UpSampling2D((2, 2))(h)
    output_layer = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(h)

    return Model([input_layer, input_layer_blur, input_layer_canny_diate_erode, input_threshold_binary, input_threshold_gaussian, input_threshold_mean, input_autoencoder], output_layer)

autoencoder = create_deep_conv_ae()
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 258, 540, 1)]     0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 258, 540, 64)      640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 129, 270, 64)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 129, 270, 64)      36928
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 258, 540, 64)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 258, 540, 1)       577
# ...
# Total params: 38,145
# Trainable params: 38,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss',
                                       min_delta=0,
                                       patience=5,
                                       verbose=1, 
                                       mode='auto')
checkpoint = ModelCheckpoint('stacker_denoising.hdf5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
history = autoencoder.fit([x_train, x_train_blur, x_train_canny_dilate_erode, x_train_threshold_binary, x_train_threshold_gaussian, x_train_threshold_mean, x_train_autoencoder], y_train,
                         batch_size=BS,
                         epochs=EPOCHS,
                         validation_data=([x_val, x_val_blur, x_val_canny_dilate_erode, x_val_threshold_binary, x_val_threshold_gaussian, x_val_threshold_mean, x_val_autoencoder], y_val),
                         callbacks=[early_stopping, checkpoint]
                        )
# Out:
# Train on 122 samples, validate on 22 samples
# Epoch 1/1000
# 120/122 [============================>.] - ETA: 0s - loss: 0.1835
# Epoch 00001: val_loss improved from inf to 0.08241, saving model to stacker_denoising.hdf5
# 122/122 [==============================] - 3s 25ms/sample - loss: 0.1821 - val_loss: 0.0824
# Epoch 2/1000
# 120/122 [============================>.] - ETA: 0s - loss: 0.0728
# Epoch 00002: val_loss improved from 0.08241 to 0.07512, saving model to stacker_denoising.hdf5
# 122/122 [==============================] - 1s 8ms/sample - loss: 0.0730 - val_loss: 0.0751
# Epoch 3/1000
# 120/122 [============================>.] - ETA: 0s - loss: 0.0743
# Epoch 00003: val_loss improved from 0.07512 to 0.07483, saving model to stacker_denoising.hdf5
# 122/122 [==============================] - 1s 8ms/sample - loss: 0.0745 - val_loss: 0.0748
# Epoch 4/1000
# 120/122 [============================>.] - ETA: 0s - loss: 0.0691
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
stacker = load_model('stacker_denoising.hdf5')
decoded_imgs = stacker.predict([x_test, x_test_blur, x_test_canny_dilate_erode, x_test_threshold_binary, x_test_threshold_gaussian, x_test_threshold_mean, x_test_autoencoder])

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n+1):
#     # display original
#     ax = plt.subplot(2, n, i)
#     plt.imshow(x_test[i].reshape(28, 28))
#     plt.gray()
#     ax.get_xaxis().set_visible(False)
#     ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(IMG_W, IMG_H))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
image_file = 'train/77.png'
# Load the image and convert it to grayscale
img = cv2.imread(image_file)
plt.imshow(img)
plt.show()

img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img)
plt.show()

ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
plt.imshow(th1)
plt.show()

#### Main param to tune is pixel region (second to last)

th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,65,2)
plt.imshow(th2)
plt.show()


th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,105,2)
plt.imshow(th3)
plt.show()

# %%
#Thresholding (2 adaptive one regular. Article used gaussian)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) #needed for thresholding functions to work
plt.imshow(img)
plt.show()
ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
plt.imshow(th1)
plt.show()
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)
plt.imshow(th2)
plt.show()
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)
plt.imshow(th3)
plt.show()
